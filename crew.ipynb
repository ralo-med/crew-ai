# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["OPENAI_MODEL_NAME"] = "gpt-4.1-nano"
from crewai import Crew, Agent, Task

international_chef = Agent(
    role="International Chef",
    goal="Create ethnic cuisine recipies that are easy to cook at home",
    backstory="""
    You are an famous chef that specializes in couisine from countries all around the world.
    You know how to cook the most traditional dishes from all cultures but you also know how to adapt them for people to be able to cook them at home.
    """,
    verbose=True,
    allow_delegation=False,
)

healthy_chef = Agent(
    role="Healthy Chef",
    goal="Turn any recipe into a healthy vegetarian recipe that is easy to cook with home ingredients.",
    backstory="""
    You are a chef specialized in healthy cooking.
    You can take any recipe and change the ingredients to make it vegetarian friendly without loosing the escense of the dish and what makes it delicious.
    """,
    verbose=True,
    allow_delegation=False,
)
normal_recipe = Task(
    description="Come up with a {dish} that serves {people} people.",
    agent=international_chef,
    expected_output="Your answer MUST have three sections, the ingredients required with their quantities, the preparation instructions and serving suggestions",
    output_file="normal_recipe.md",
)

healthy_recipe = Task(
    description="Replace the ingredients of a recipe to make it vegetarian without making it less delicious, adjust if needed.",
    agent=healthy_chef,
    expected_output="Your answer MUST have four sections, the ingredients required with their quantities, the preparation instructions, serving suggestions and an explanation of the replaced ingredients.",
    output_file="healthy_recipe.md",
)
crew = Crew(
    tasks=[
        normal_recipe,
        healthy_recipe,
    ],
    agents=[
        international_chef,
        healthy_chef,
    ],
    verbose=True,
)

result = crew.kickoff(
    inputs=dict(
        dish="Greek dinner",
        people="5",
    )
)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: f8e67c05-dccb-440f-a12f-7661ea2fe9e9                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: International Chef                                                                                      │
# │                                                                                                                 │
# │  Task: Come up with a Greek dinner that serves 5 people.                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: International Chef                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Greek Dinner for 5 People**                                                                                  │
# │                                                                                                                 │
# │  **Ingredients:**                                                                                               │
# │                                                                                                                 │
# │  *Main Dish - Greek Chicken Souvlaki:*                                                                          │
# │  - 2.5 lbs (1.2 kg) boneless, skinless chicken breasts or thighs, cut into 1-inch pieces                        │
# │  - 3 tablespoons olive oil                                                                                      │
# │  - 3 cloves garlic, minced                                                                                      │
# │  - 2 teaspoons dried oregano                                                                                    │
# │  - 1 teaspoon lemon zest                                                                                        │
# │  - 2 tablespoons lemon juice                                                                                    │
# │  - 1 teaspoon salt                                                                                              │
# │  - ½ teaspoon black pepper                                                                                      │
# │  - Wooden skewers (soaked in water for 30 minutes)                                                              │
# │                                                                                                                 │
# │  *Side Dish 1 - Greek Village Salad (Horiatiki):*                                                               │
# │  - 3 large ripe tomatoes, cut into wedges                                                                       │
# │  - 1 cucumber, sliced                                                                                           │
# │  - 1 red onion, thinly sliced                                                                                   │
# │  - ½ cup Kalamata olives                                                                                        │
# │  - 200g feta cheese, sliced or crumbled                                                                         │
# │  - 2 tablespoons extra virgin olive oil                                                                         │
# │  - 1 tablespoon red wine vinegar                                                                                │
# │  - 1 teaspoon dried oregano                                                                                     │
# │  - Salt and freshly ground black pepper to taste                                                                │
# │                                                                                                                 │
# │  *Side Dish 2 - Tzatziki Sauce:*                                                                                │
# │  - 1 cup Greek yogurt                                                                                           │
# │  - 1 cucumber, finely grated and drained                                                                        │
# │  - 2 cloves garlic, minced                                                                                      │
# │  - 1 tablespoon olive oil                                                                                       │
# │  - 1 tablespoon lemon juice                                                                                     │
# │  - 2 tablespoons fresh dill, chopped                                                                            │
# │  - Salt and pepper to taste                                                                                     │
# │                                                                                                                 │
# │  *Bread:*                                                                                                       │
# │  - 5 warm pita breads                                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Preparation Instructions:**                                                                                  │
# │                                                                                                                 │
# │  1. **Marinate the Chicken (Souvlaki):**                                                                        │
# │      - In a bowl, combine olive oil, minced garlic, oregano, lemon zest, lemon juice, salt, and pepper.         │
# │      - Add chicken pieces and toss to coat evenly. Cover and refrigerate for at least 30 minutes, preferably    │
# │  1-2 hours.                                                                                                     │
# │                                                                                                                 │
# │  2. **Prepare the Tzatziki Sauce:**                                                                             │
# │      - In a bowl, mix Greek yogurt, grated cucumber, minced garlic, olive oil, lemon juice, dill, salt, and     │
# │  pepper.                                                                                                        │
# │      - Chill in the refrigerator while preparing other components to allow flavors to meld.                     │
# │                                                                                                                 │
# │  3. **Assemble the Village Salad:**                                                                             │
# │      - In a large bowl, combine tomatoes, cucumber, red onion, and olives.                                      │
# │      - Drizzle with olive oil and red wine vinegar.                                                             │
# │      - Sprinkle with oregano, salt, and pepper.                                                                 │
# │      - Top with feta cheese slices or crumbles.                                                                 │
# │                                                                                                                 │
# │  4. **Cook the Chicken Souvlaki:**                                                                              │
# │      - Preheat a grill or grill pan over medium-high heat.                                                      │
# │      - Thread marinated chicken onto soaked skewers.                                                            │
# │      - Grill skewers for 4-5 minutes per side, until fully cooked and slightly charred.                         │
# │                                                                                                                 │
# │  5. **Warm the Pita Breads:**                                                                                   │
# │      - Lightly toast or warm pita breads in the oven or on a dry skillet until soft and slightly crispy.        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Serving Suggestions:**                                                                                       │
# │                                                                                                                 │
# │  - Place the grilled chicken souvlaki on a platter with lemon wedges for extra flavor.                          │
# │  - Serve the village salad in a large bowl alongside the skewers.                                               │
# │  - Present the chilled tzatziki in a small bowl for dipping.                                                    │
# │  - Arrange warm pita breads on a plate or basket, allowing guests to make their own wraps.                      │
# │                                                                                                                 │
# │  **Presentation:**                                                                                              │
# │  Arrange everything on a large Greek-themed platter or table. Garnish the chicken with fresh herbs like         │
# │  parsley or oregano if desired. Encourage guests to assemble their own pita wraps with chicken, vegetables,     │
# │  and a dollop of tzatziki for a fun, interactive experience.                                                    │
# │                                                                                                                 │
# │  Enjoy your authentic Greek dinner at home, full of vibrant flavors and fresh ingredients!                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 88ef01a8-1466-4adf-b903-b0925f15fa61                                                                     │
# │  Agent: International Chef                                                                                      │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Healthy Chef                                                                                            │
# │                                                                                                                 │
# │  Task: Replace the ingredients of a recipe to make it vegetarian without making it less delicious, adjust if    │
# │  needed.                                                                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Healthy Chef                                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Ingredients (Vegetarian Greek Souvlaki & Accompaniments for 5 People:**                                      │
# │                                                                                                                 │
# │  *Main Dish - Vegetarian Greek Souvlaki:*                                                                       │
# │  - 2 lbs (900 g) firm tofu or tempeh, cut into 1-inch cubes (as a plant-based protein alternative)              │
# │  - 3 tablespoons olive oil                                                                                      │
# │  - 3 cloves garlic, minced                                                                                      │
# │  - 2 teaspoons dried oregano                                                                                    │
# │  - 1 teaspoon lemon zest                                                                                        │
# │  - 2 tablespoons lemon juice                                                                                    │
# │  - 1 teaspoon salt                                                                                              │
# │  - ½ teaspoon black pepper                                                                                      │
# │  - Wooden skewers (soaked in water for 30 minutes)                                                              │
# │                                                                                                                 │
# │  *Side Dish 1 - Greek Village Salad (Horiatiki):*                                                               │
# │  - 3 large ripe tomatoes, cut into wedges                                                                       │
# │  - 1 cucumber, sliced                                                                                           │
# │  - 1 red onion, thinly sliced                                                                                   │
# │  - ½ cup Kalamata olives                                                                                        │
# │  - 200g feta cheese, sliced or crumbled (can substitute with vegan feta if preferred for fully vegetarian       │
# │  option)                                                                                                        │
# │  - 2 tablespoons extra virgin olive oil                                                                         │
# │  - 1 tablespoon red wine vinegar                                                                                │
# │  - 1 teaspoon dried oregano                                                                                     │
# │  - Salt and freshly ground black pepper to taste                                                                │
# │                                                                                                                 │
# │  *Side Dish 2 - Tzatziki Sauce:*                                                                                │
# │  - 1 cup Greek-style plant-based yogurt (such as coconut or almond-based yogurt) or traditional Greek yogurt    │
# │  for lacto-vegetarian                                                                                           │
# │  - 1 cucumber, finely grated and drained                                                                        │
# │  - 2 cloves garlic, minced                                                                                      │
# │  - 1 tablespoon olive oil                                                                                       │
# │  - 1 tablespoon lemon juice                                                                                     │
# │  - 2 tablespoons fresh dill, chopped                                                                            │
# │  - Salt and pepper to taste                                                                                     │
# │                                                                                                                 │
# │  *Bread:*                                                                                                       │
# │  - 5 warm pita breads                                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Preparation Instructions:**                                                                                  │
# │                                                                                                                 │
# │  1. **Marinate the Tofu/Tempeh (Vegetarian Souvlaki):**                                                         │
# │      - In a bowl, mix olive oil, minced garlic, oregano, lemon zest, lemon juice, salt, and pepper.             │
# │      - Add tofu or tempeh cubes and toss gently to coat all pieces evenly.                                      │
# │      - Cover and refrigerate for at least 30 minutes, preferably 1-2 hours, to absorb flavors.                  │
# │                                                                                                                 │
# │  2. **Prepare the Tzatziki Sauce:**                                                                             │
# │      - In a bowl, combine Greek-style plant-based yogurt (or traditional yogurt), grated cucumber, minced       │
# │  garlic, olive oil, lemon juice, dill, salt, and pepper.                                                        │
# │      - Mix well, cover, and chill to allow flavors to meld.                                                     │
# │                                                                                                                 │
# │  3. **Assemble the Village Salad:**                                                                             │
# │      - In a large bowl, combine tomatoes, cucumber, red onion, and olives.                                      │
# │      - Drizzle with olive oil and red wine vinegar.                                                             │
# │      - Sprinkle with oregano, salt, and pepper.                                                                 │
# │      - Top with feta or vegan feta cheese if desired.                                                           │
# │                                                                                                                 │
# │  4. **Cook the Vegetarian Skewers:**                                                                            │
# │      - Preheat a grill or grill pan over medium-high heat.                                                      │
# │      - Thread tofu or tempeh onto the soaked skewers.                                                           │
# │      - Grill for 4-5 minutes per side, until lightly charred and heated through.                                │
# │                                                                                                                 │
# │  5. **Warm the Pita Breads:**                                                                                   │
# │      - Toast or warm pita breads in the oven or on a dry skillet until soft and slightly crispy.                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Serving Suggestions:**                                                                                       │
# │                                                                                                                 │
# │  - Arrange the grilled vegetarian skewers on a platter with lemon wedges for added zest.                        │
# │  - Serve the village salad in a large bowl, garnished with herbs if desired.                                    │
# │  - Place the chilled plant-based tzatziki in a small bowl for dipping.                                          │
# │  - Set out the warm pita breads, allowing guests to assemble their own wraps with the grilled tofu or tempeh,   │
# │  vegetables, and tzatziki.                                                                                      │
# │                                                                                                                 │
# │  **Presentation:**                                                                                              │
# │  Display everything on a traditional Greek-themed platter or table. Garnish the skewers with fresh herbs like   │
# │  parsley or oregano. Encourage guests to enjoy customizable wraps, creating a fun and healthy dining            │
# │  experience filled with fresh, vibrant flavors.                                                                 │
# │                                                                                                                 │
# │  This vegetarian adaptation maintains the essence and deliciousness of the original Greek Dinner, utilizing     │
# │  tofu or tempeh as hearty, protein-rich options that absorb flavors well, paired with fresh vegetables and      │
# │  herbs to keep the dishes vibrant and satisfying.                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: b97270b2-7876-4982-acc6-48aa76d17405                                                                     │
# │  Agent: Healthy Chef                                                                                            │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: f8e67c05-dccb-440f-a12f-7661ea2fe9e9                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: **Ingredients (Vegetarian Greek Souvlaki & Accompaniments for 5 People:**                        │
# │                                                                                                                 │
# │  *Main Dish - Vegetarian Greek Souvlaki:*                                                                       │
# │  - 2 lbs (900 g) firm tofu or tempeh, cut into 1-inch cubes (as a plant-based protein alternative)              │
# │  - 3 tablespoons olive oil                                                                                      │
# │  - 3 cloves garlic, minced                                                                                      │
# │  - 2 teaspoons dried oregano                                                                                    │
# │  - 1 teaspoon lemon zest                                                                                        │
# │  - 2 tablespoons lemon juice                                                                                    │
# │  - 1 teaspoon salt                                                                                              │
# │  - ½ teaspoon black pepper                                                                                      │
# │  - Wooden skewers (soaked in water for 30 minutes)                                                              │
# │                                                                                                                 │
# │  *Side Dish 1 - Greek Village Salad (Horiatiki):*                                                               │
# │  - 3 large ripe tomatoes, cut into wedges                                                                       │
# │  - 1 cucumber, sliced                                                                                           │
# │  - 1 red onion, thinly sliced                                                                                   │
# │  - ½ cup Kalamata olives                                                                                        │
# │  - 200g feta cheese, sliced or crumbled (can substitute with vegan feta if preferred for fully vegetarian       │
# │  option)                                                                                                        │
# │  - 2 tablespoons extra virgin olive oil                                                                         │
# │  - 1 tablespoon red wine vinegar                                                                                │
# │  - 1 teaspoon dried oregano                                                                                     │
# │  - Salt and freshly ground black pepper to taste                                                                │
# │                                                                                                                 │
# │  *Side Dish 2 - Tzatziki Sauce:*                                                                                │
# │  - 1 cup Greek-style plant-based yogurt (such as coconut or almond-based yogurt) or traditional Greek yogurt    │
# │  for lacto-vegetarian                                                                                           │
# │  - 1 cucumber, finely grated and drained                                                                        │
# │  - 2 cloves garlic, minced                                                                                      │
# │  - 1 tablespoon olive oil                                                                                       │
# │  - 1 tablespoon lemon juice                                                                                     │
# │  - 2 tablespoons fresh dill, chopped                                                                            │
# │  - Salt and pepper to taste                                                                                     │
# │                                                                                                                 │
# │  *Bread:*                                                                                                       │
# │  - 5 warm pita breads                                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Preparation Instructions:**                                                                                  │
# │                                                                                                                 │
# │  1. **Marinate the Tofu/Tempeh (Vegetarian Souvlaki):**                                                         │
# │      - In a bowl, mix olive oil, minced garlic, oregano, lemon zest, lemon juice, salt, and pepper.             │
# │      - Add tofu or tempeh cubes and toss gently to coat all pieces evenly.                                      │
# │      - Cover and refrigerate for at least 30 minutes, preferably 1-2 hours, to absorb flavors.                  │
# │                                                                                                                 │
# │  2. **Prepare the Tzatziki Sauce:**                                                                             │
# │      - In a bowl, combine Greek-style plant-based yogurt (or traditional yogurt), grated cucumber, minced       │
# │  garlic, olive oil, lemon juice, dill, salt, and pepper.                                                        │
# │      - Mix well, cover, and chill to allow flavors to meld.                                                     │
# │                                                                                                                 │
# │  3. **Assemble the Village Salad:**                                                                             │
# │      - In a large bowl, combine tomatoes, cucumber, red onion, and olives.                                      │
# │      - Drizzle with olive oil and red wine vinegar.                                                             │
# │      - Sprinkle with oregano, salt, and pepper.                                                                 │
# │      - Top with feta or vegan feta cheese if desired.                                                           │
# │                                                                                                                 │
# │  4. **Cook the Vegetarian Skewers:**                                                                            │
# │      - Preheat a grill or grill pan over medium-high heat.                                                      │
# │      - Thread tofu or tempeh onto the soaked skewers.                                                           │
# │      - Grill for 4-5 minutes per side, until lightly charred and heated through.                                │
# │                                                                                                                 │
# │  5. **Warm the Pita Breads:**                                                                                   │
# │      - Toast or warm pita breads in the oven or on a dry skillet until soft and slightly crispy.                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Serving Suggestions:**                                                                                       │
# │                                                                                                                 │
# │  - Arrange the grilled vegetarian skewers on a platter with lemon wedges for added zest.                        │
# │  - Serve the village salad in a large bowl, garnished with herbs if desired.                                    │
# │  - Place the chilled plant-based tzatziki in a small bowl for dipping.                                          │
# │  - Set out the warm pita breads, allowing guests to assemble their own wraps with the grilled tofu or tempeh,   │
# │  vegetables, and tzatziki.                                                                                      │
# │                                                                                                                 │
# │  **Presentation:**                                                                                              │
# │  Display everything on a traditional Greek-themed platter or table. Garnish the skewers with fresh herbs like   │
# │  parsley or oregano. Encourage guests to enjoy customizable wraps, creating a fun and healthy dining            │
# │  experience filled with fresh, vibrant flavors.                                                                 │
# │                                                                                                                 │
# │  This vegetarian adaptation maintains the essence and deliciousness of the original Greek Dinner, utilizing     │
# │  tofu or tempeh as hearty, protein-rich options that absorb flavors well, paired with fresh vegetables and      │
# │  herbs to keep the dishes vibrant and satisfying.                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
